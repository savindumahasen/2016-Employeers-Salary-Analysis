# %% [markdown]
# <a href="https://colab.research.google.com/github/savindumahasen/2016-Employeers-Salary-Analysis/blob/main/Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install the necessary libraries
# !pip install pandas
# !pip install numpy
# !pip install opendatasets

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import opendatasets as od

# %%
## download the dataset
od.download("https://www.kaggle.com/datasets/shanegerami/ai-vs-human-text")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: savinduruhunuhewa
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/shanegerami/ai-vs-human-text
# ...
# 100%|██████████| 350M/350M [00:00<00:00, 661MB/s]
